# %%
import pandas as pd
scenario = 'commons_harvest__open_0'
scenario_results = pd.read_feather('../data/melting_pot_2_scenario_results.feather')
scenario_results = scenario_results.reset_index()
# filter by scenario
scenario_results = scenario_results[scenario_results['scenario'] == scenario]

# %%
scenario_results
# Out:
#                      scenario              substrate           mapla  \
# 1638  commons_harvest__open_0  commons_harvest__open             acb
# 1639  commons_harvest__open_0  commons_harvest__open             acb
# 1640  commons_harvest__open_0  commons_harvest__open             acb
# 1641  commons_harvest__open_0  commons_harvest__open   acb_prosocial
# 1642  commons_harvest__open_0  commons_harvest__open   acb_prosocial
# 1643  commons_harvest__open_0  commons_harvest__open   acb_prosocial
# 1644  commons_harvest__open_0  commons_harvest__open       exploiter
# 1645  commons_harvest__open_0  commons_harvest__open            opre
# 1646  commons_harvest__open_0  commons_harvest__open            opre
# 1647  commons_harvest__open_0  commons_harvest__open            opre
# 1648  commons_harvest__open_0  commons_harvest__open  opre_prosocial
# 1649  commons_harvest__open_0  commons_harvest__open  opre_prosocial
# 1650  commons_harvest__open_0  commons_harvest__open  opre_prosocial
# 1651  commons_harvest__open_0  commons_harvest__open          random
# 1652  commons_harvest__open_0  commons_harvest__open            vmpo
# 1653  commons_harvest__open_0  commons_harvest__open            vmpo
#
#       training_run  focal_per_capita_return
# 1638             0                10.289947
# 1639             1                10.113538
# 1640             2                10.392086
# 1641             0                10.769975
# 1642             1                10.743022
# 1643             2                11.553763
# 1644             0                10.673418
# 1645             0                10.009270
# 1646             1                 9.814328
# 1647             2                10.111189
# 1648             0                 6.675784
# 1649             1                 6.410153
# 1650             2                 7.794464
# 1651             0                 1.813636
# 1652             1                10.746139
# 1653             2                11.052803

# %%
1+1
